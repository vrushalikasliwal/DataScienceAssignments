# %% [markdown]
# # Assignments BasicStatestics Q_12

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wng

# %matplotlib inline
wng.filterwarnings('ignore')

# %%
a=np.array([34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56])

# %%
a.ndim
# Out:
# 1

# %%
a=pd.DataFrame(a)

# %%
a.describe()
# Out:
#                0
# count  18.000000
# mean   41.000000
# std     5.052664
# min    34.000000
# 25%    38.250000
# 50%    40.500000
# 75%    41.750000
# max    56.000000

# %%
a.median()
# Out:
# 0    40.5
# dtype: float64

# %%
b=a.std()
b=b*b
b
# Out:
# 0    25.529412
# dtype: float64

# %%
plt.boxplot(a,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x243601c7af0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2435fa03c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x243601c72b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2435d530730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24359ac4b20>],
#  'means': []}

# %%
plt.hist(a)
# Out:
# (array([3., 2., 4., 6., 0., 1., 1., 0., 0., 1.]),
#  array([34. , 36.2, 38.4, 40.6, 42.8, 45. , 47.2, 49.4, 51.6, 53.8, 56. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(a)

# %%
sns.kdeplot(a[0])
# Out:
# <AxesSubplot:xlabel='0', ylabel='Density'>
